# %%
import pandas as pd
import numpy as np
import matplotlib
import json as json
import urllib
import urllib2
import cookielib
import re
#import BeautifulSoup

# %%
API_KEY = "5433abdd87a947f8ad94b5d8f2ef3d7d"

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
url = "https://newsapi.org/v1/sources?language=en"
response = urllib.urlopen(url)
data = json.loads(response.read())

# %%
data = pd.DataFrame(data['sources'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 9 columns):
# category            60 non-null object
# country             60 non-null object
# description         60 non-null object
# id                  60 non-null object
# language            60 non-null object
# name                60 non-null object
# sortBysAvailable    60 non-null object
# url                 60 non-null object
# urlsToLogos         60 non-null object
# dtypes: object(9)
# memory usage: 4.7+ KB

# %%
data = data.loc[data['language'] == "en"]
news_providers = pd.unique(data.id)
news_types = pd.unique(data.category)
len(news_providers)
len(news_types)
type(news_providers)
# Out:
# 60
# 9
# numpy.ndarray

# %%
def news_sources(news_provider):
    url = "https://newsapi.org/v1/articles?source=" + news_provider +"&apiKey=" +API_KEY
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    return(data)

# %%
#df3 = data.apply(lambda x: news_sources(x['news_providers'], axis=1))
data
# Out:
#               category country  \
# 0              general      au
# 1              general      us
# 2           technology      us
# 3              general      us
# 4              general      gb
# 5                sport      gb
# 6             business      us
# 7             politics      us
# 8             business      us
# 9             business      gb
# 10       entertainment      us
# 11            business      us
# 12             general      us
# 13       entertainment      gb
# 14          technology      us
# 15       entertainment      us
# 16               sport      us
# 17               sport      us
# 18            business      gb
# 19               sport      it
# 20            business      us
# 21               sport      gb
# 22               sport      us
# 23             general      us
# 24          technology      us
# 25              gaming      us
# 26             general      gb
# 27       entertainment      us
# 28             general      gb
# ...

# %%
new_data = []
for i in data.iterrows():
        print(data.id[i])
            #new_data.append(news_sources(id))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-04ff40a0c2b0> in <module>()
#       1 new_data = []
#       2 for i in data.iterrows():
# ----> 3         print(data.id[i])
#       4             #new_data.append(news_sources(id))
#
# /home/hive2a5/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     642             key = check_bool_indexer(self.index, key)
#     643
# --> 644         return self._get_with(key)
#     645
#     646     def _get_with(self, key):
#
# /home/hive2a5/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     655             if isinstance(key, tuple):
#     656                 try:
# --> 657                     return self._get_values_tuple(key)
#     658                 except:
#     659                     if len(key) == 1:
#
# ...
